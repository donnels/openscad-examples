# %% [markdown]
# # TP-link MR 3020 Holder
# to hang an mr3020 on the wall as an AP.

# %% [markdown]
# ## some commands to manipulate the notebook

# %%
%lsmagic
# Out:
# Available Commands: %clear %display %displayCode %%display %%displayCode %mime %command %lsmagic %include %use %saveAs

# %%
sphere(3, $fn=50 );
# Out:
# Number of lines of OpenSCAD code: 1

# %% [markdown]
# ### to display the code up to this point

# %%
%mime text/plain
%display
# Out:
# The display mime type is 'text/plain'
# sphere(3, $fn=50 );

# %% [markdown]
# ### to display images again

# %%
%mime image/png
%display
# Out:
# The display mime type is 'image/png'Compiling design (CSG Products normalization)...
# Normalized CSG tree has 1 elements

# %% [markdown]
# ## initial measurements
# - 6.7cm wide
# - 7.4cm deep
# - 2.2cm high
# rounded corners
# ethernet port
# usb port and micro usb port for power
# swith on side and leds and button on top

# %%
// Router
height=22;
//width=67;
width=67;
//depth=74;
depth=74;
#cube([width,depth,height]);
# Out:
# Number of lines of OpenSCAD code: 8

# %% [markdown]
# ## the initial Cube without rounded corners

# %%
%display
# Out:
# Compiling design (CSG Products normalization)...
# Normalized CSG tree has 1 elements
# Compiling highlights (1 CSG Trees)...

# %% [markdown]
# ## adding the subtraction points for the rounded corners

# %%
cubeSide=6;
cubeSize=[cubeSide+1,cubeSide+1,height+2];
cube(cubeSize);
translate ([width-cubeSide,0,-1]) cube(cubeSize);
translate ([width-cubeSide,depth-cubeSide,-1]) cube(cubeSize);
translate ([0,depth-cubeSide,-1]) cube(cubeSize);
# Out:
# Number of lines of OpenSCAD code: 14

# %%
%display
# Out:
# Compiling design (CSG Products normalization)...
# Normalized CSG tree has 5 elements
# Compiling highlights (1 CSG Trees)...

# %% [markdown]
# ## adding the top LEDs

# %%
//LEDs on top
ledsOffset=[8,14,-1];
ledsSize=[2,40,2];
translate (ledsOffset+[0,0,height]) color([0,1,0]) cube(ledsSize);
# Out:
# Number of lines of OpenSCAD code: 18

# %%
%display
# Out:
# Compiling design (CSG Products normalization)...
# Normalized CSG tree has 6 elements
# Compiling highlights (1 CSG Trees)...

# %% [markdown]
# ## Adding the ethernet port

# %% [markdown]
# The ethernet port is shown extruded so as to be easily subtracted from the holder.

# %%
//ethernet port on side
eth3D=40;
ethSize=[19.5,eth3D,13];
ethOffset=[21,-(eth3D/2),6.7];
translate (ethOffset+[0,0,0]) color([0,1,0]) cube(ethSize);
# Out:
# Number of lines of OpenSCAD code: 23

# %%
%display
# Out:
# Compiling design (CSG Products normalization)...
# Normalized CSG tree has 7 elements
# Compiling highlights (1 CSG Trees)...

# %% [markdown]
# ## Adding the Power Port
# The Power Port is shown extruded to be easily subtracted from the main body.

# %%
//power connexion on side
pwr3D=40;
pwrSize=[12.3,pwr3D,5];
pwrOffset=[42,-(pwr3D/2),6];
translate (pwrOffset+[0,0,0]) color([1,0,0]) cube(pwrSize);
# Out:
# Number of lines of OpenSCAD code: 28

# %%
%display
# Out:
# Compiling design (CSG Products normalization)...
# Normalized CSG tree has 8 elements
# Compiling highlights (1 CSG Trees)...

# %% [markdown]
# ## Adding the switch on the side of Power- and LAN ports
# The switch is extruded to be easily substracted from the main body.

# %%
//Mode switch
swt3D=40;
swtSize=[7.1,swt3D,3.6];
swtOffset=[12,-(swt3D/2),5.2];
translate (swtOffset+[0,0,0]) color([0,0,1]) cube(swtSize);
# Out:
# Number of lines of OpenSCAD code: 33

# %%
%display
# Out:
# Compiling design (CSG Products normalization)...
# Normalized CSG tree has 9 elements
# Compiling highlights (1 CSG Trees)...

# %% [markdown]
# ## Adding the USB Port on it's  own side
# The USB Port is extruded to be easily substracted from the main body.

# %%
//USB Port
USB3D=40;
USBSize=[USB3D,14.5,6.9];
USBOffset=[width-(USB3D/2),11,8.5];
translate (USBOffset) color([1,1,1]) cube(USBSize);
# Out:
# Number of lines of OpenSCAD code: 38

# %%
%display
# Out:
# Compiling design (CSG Products normalization)...
# Normalized CSG tree has 10 elements
# Compiling highlights (1 CSG Trees)...
